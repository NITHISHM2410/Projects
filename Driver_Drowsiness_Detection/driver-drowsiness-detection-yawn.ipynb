# %%
import numpy as np
import pandas as pd
import tensorflow as tf
tf.random.set_seed(42)
import matplotlib.pyplot as plt
from distutils.dir_util import copy_tree
from glob import glob
import PIL
from PIL import Image
import cv2
import os
import shutil
import random
import math
import tensorflow_datasets as tfds

# %%
def _bytes_feature(value):
    if isinstance(value, type(tf.constant(0))): 
        value = value.numpy() 
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

# %%
def serialize_example(image,label):
    feature = {
        'image':tf.train.Feature(bytes_list=tf.train.BytesList(value=[image])),
        'label':_bytes_feature(tf.io.serialize_tensor(label))
    }
    example = tf.train.Example(features=tf.train.Features(feature=feature))
    return example.SerializeToString()

# %%
# !mkdir images

# %%
def tf_writer(op_path,filelist):
    classes=['yawn','no_yawn']
    with tf.io.TFRecordWriter(op_path) as writer:
                random.shuffle(filelist)
                for fn in filelist:
                    label = np.array([0,0],dtype='float64')
                    img = open(fn,'rb').read()
                    lab = fn.split('/')[-2]
                    lab = classes.index(lab)
                    label[lab] = 1.0
                    tf_example = serialize_example(img,label)
                    writer.write(tf_example)

# %%
def create_records(path):
    opr1 = "./images/train_rec"
    opr2 = "./images/val_rec"
    classes=['yawn','no_yawn']
    files_list = glob(path+'/no_yawn/*')
    files_list1 = glob(path+'/yawn/*')
    train_list = files_list[:math.ceil(len(files_list)*0.8)]  +  files_list1[:math.ceil(len(files_list1)*0.8)]
    val_list = files_list[math.ceil(len(files_list)*0.8):]  +  files_list1[math.ceil(len(files_list1)*0.8):]
    tf_writer(opr1,train_list)
    tf_writer(opr2,val_list)

# %%
create_records('../input/drowsiness-dataset/train')
# Out:
# 2023-02-21 08:17:42.623585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:42.745607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:42.746485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:42.749125: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-21 08:17:42.750284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:42.750993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:42.751626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:45.061027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:45.061921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:45.062651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 08:17:45.063270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
def parse_image(example):
    feature = {'image':tf.io.FixedLenFeature([],tf.string),
              'label':tf.io.FixedLenFeature([],tf.string)}
    features = tf.io.parse_single_example(example,feature)
    image = tf.io.decode_jpeg(features['image'],channels = 3)
    image = tf.image.resize(image,[256,256])
    label = tf.io.parse_tensor(features['label'], out_type=tf.float64)
    label = tf.reshape(label,shape=(2,))
    return image,label

# %%
def read_dataset(filename,batchs):
    data = tf.data.TFRecordDataset(filename)
    ds = configure(data)
    return ds

# %%
def configure(data):
    data = data.map(parse_image,num_parallel_calls = tf.data.experimental.AUTOTUNE)
    data = data.shuffle(500)
    data = data.batch(32,drop_remainder = True)
    data = data.repeat()
    data = data.prefetch(buffer_size = tf.data.experimental.AUTOTUNE)
    return data

# %%
def use_records():
    train = read_dataset("./images/train_rec",32)
    val = read_dataset("./images/val_rec",32)
    return train,val
train_ds,val_ds= use_records()

# %%
train_ds,val_ds
# Out:
# (<PrefetchDataset shapes: ((32, 256, 256, 3), (32, 2)), types: (tf.float32, tf.float64)>,
#  <PrefetchDataset shapes: ((32, 256, 256, 3), (32, 2)), types: (tf.float32, tf.float64)>)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy().shape)
# Out:
# 2023-02-21 08:17:56.240536: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Image shape:  (32, 256, 256, 3)
# Label:  (32, 2)

# %%
for image, label in val_ds.take(1):
  print("Label: ", label.numpy()[0])
  plt.imshow(image.numpy()[0].astype("uint8"))
# Out:
# Label:  [1. 0.]

# %%
# Label [0,1] => No Yawn  
# Label [1,0] =>  Yawn - Alert

# %%
cb = [tf.keras.callbacks.ModelCheckpoint("./first_model.h5",monitor='val_accuracy',save_best_only=True,mode='max')]

# %%
def build():
  model = tf.keras.Sequential([
  tf.keras.layers.Resizing(256,256),
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.RandomFlip(mode="horizontal"),
  tf.keras.layers.RandomRotation(0.2, fill_mode='reflect',interpolation='bilinear'),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(2,activation='softmax')
 ])
  model.compile(
  optimizer='adam',
  loss=tf.losses.CategoricalCrossentropy(),
  metrics=['accuracy'])
  return model

# %%
model = build()

# %%
deep_model = model.fit(train_ds,steps_per_epoch=math.ceil(2320/32),validation_data=val_ds,validation_steps = math.ceil(580/32),epochs =30,callbacks=cb)
# Out:
# Epoch 1/30
# 2023-02-21 08:18:02.622727: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 73/73 [==============================] - 18s 122ms/step - loss: 0.6629 - accuracy: 0.5826 - val_loss: 0.6163 - val_accuracy: 0.6151
# Epoch 2/30
# 73/73 [==============================] - 10s 142ms/step - loss: 0.5780 - accuracy: 0.6678 - val_loss: 0.5933 - val_accuracy: 0.6464
# Epoch 3/30
# 73/73 [==============================] - 9s 123ms/step - loss: 0.5610 - accuracy: 0.6772 - val_loss: 0.5955 - val_accuracy: 0.6316
# Epoch 4/30
# 73/73 [==============================] - 8s 109ms/step - loss: 0.5683 - accuracy: 0.6764 - val_loss: 0.6234 - val_accuracy: 0.6299
# Epoch 5/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.5472 - accuracy: 0.6922 - val_loss: 0.5845 - val_accuracy: 0.6283
# Epoch 6/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.5271 - accuracy: 0.7085 - val_loss: 0.5700 - val_accuracy: 0.7138
# Epoch 7/30
# 73/73 [==============================] - 9s 121ms/step - loss: 0.5061 - accuracy: 0.7359 - val_loss: 0.5337 - val_accuracy: 0.7336
# Epoch 8/30
# 73/73 [==============================] - 8s 112ms/step - loss: 0.4911 - accuracy: 0.7432 - val_loss: 0.4928 - val_accuracy: 0.7582
# Epoch 9/30
# 73/73 [==============================] - 6s 85ms/step - loss: 0.4102 - accuracy: 0.8193 - val_loss: 0.3883 - val_accuracy: 0.8503
# Epoch 10/30
# 73/73 [==============================] - 9s 118ms/step - loss: 0.3610 - accuracy: 0.8420 - val_loss: 0.9211 - val_accuracy: 0.6579
# Epoch 11/30
# 73/73 [==============================] - 7s 95ms/step - loss: 0.3825 - accuracy: 0.8395 - val_loss: 0.3978 - val_accuracy: 0.8339
# Epoch 12/30
# 73/73 [==============================] - 9s 125ms/step - loss: 0.2679 - accuracy: 0.8930 - val_loss: 0.2094 - val_accuracy: 0.9095
# Epoch 13/30
# 73/73 [==============================] - 7s 103ms/step - loss: 0.2205 - accuracy: 0.9182 - val_loss: 0.2897 - val_accuracy: 0.8849
# Epoch 14/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.1914 - accuracy: 0.9255 - val_loss: 0.1871 - val_accuracy: 0.9309
# Epoch 15/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.1634 - accuracy: 0.9414 - val_loss: 0.2201 - val_accuracy: 0.9046
# Epoch 16/30
# 73/73 [==============================] - 8s 112ms/step - loss: 0.1634 - accuracy: 0.9426 - val_loss: 0.2033 - val_accuracy: 0.9260
# Epoch 17/30
# 73/73 [==============================] - 6s 86ms/step - loss: 0.1401 - accuracy: 0.9499 - val_loss: 0.1997 - val_accuracy: 0.9260
# Epoch 18/30
# 73/73 [==============================] - 9s 123ms/step - loss: 0.1043 - accuracy: 0.9640 - val_loss: 0.1830 - val_accuracy: 0.9293
# Epoch 19/30
# 73/73 [==============================] - 8s 105ms/step - loss: 0.1044 - accuracy: 0.9580 - val_loss: 0.1558 - val_accuracy: 0.9457
# Epoch 20/30
# 73/73 [==============================] - 8s 107ms/step - loss: 0.1004 - accuracy: 0.9658 - val_loss: 0.1195 - val_accuracy: 0.9589
# Epoch 21/30
# 73/73 [==============================] - 6s 84ms/step - loss: 0.1010 - accuracy: 0.9628 - val_loss: 0.2363 - val_accuracy: 0.9161
# Epoch 22/30
# 73/73 [==============================] - 7s 99ms/step - loss: 0.0823 - accuracy: 0.9717 - val_loss: 0.1753 - val_accuracy: 0.9408
# Epoch 23/30
# 73/73 [==============================] - 9s 120ms/step - loss: 0.0809 - accuracy: 0.9726 - val_loss: 0.1802 - val_accuracy: 0.9523
# Epoch 24/30
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0796 - accuracy: 0.9713 - val_loss: 0.1656 - val_accuracy: 0.9572
# Epoch 25/30
# 73/73 [==============================] - 7s 103ms/step - loss: 0.0677 - accuracy: 0.9773 - val_loss: 0.1766 - val_accuracy: 0.9276
# Epoch 26/30
# 73/73 [==============================] - 6s 83ms/step - loss: 0.0755 - accuracy: 0.9717 - val_loss: 0.1519 - val_accuracy: 0.9671
# Epoch 27/30
# 73/73 [==============================] - 9s 118ms/step - loss: 0.0544 - accuracy: 0.9829 - val_loss: 0.1982 - val_accuracy: 0.9572
# Epoch 28/30
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0526 - accuracy: 0.9833 - val_loss: 0.1214 - val_accuracy: 0.9572
# Epoch 29/30
# 73/73 [==============================] - 7s 101ms/step - loss: 0.0606 - accuracy: 0.9765 - val_loss: 0.1850 - val_accuracy: 0.9457
# Epoch 30/30
# 73/73 [==============================] - 6s 82ms/step - loss: 0.0630 - accuracy: 0.9786 - val_loss: 0.1134 - val_accuracy: 0.9704

# %%
df = pd.DataFrame(deep_model.history)
df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.662941  0.582620  0.616281      0.615132
# 1   0.577972  0.667808  0.593305      0.646382
# 2   0.561044  0.677226  0.595543      0.631579
# 3   0.568342  0.676370  0.623448      0.629934
# 4   0.547239  0.692209  0.584532      0.628289
# 5   0.527111  0.708476  0.570038      0.713816
# 6   0.506115  0.735873  0.533684      0.733553
# 7   0.491119  0.743151  0.492794      0.758224
# 8   0.410167  0.819349  0.388278      0.850329
# 9   0.361042  0.842038  0.921120      0.657895
# 10  0.382527  0.839469  0.397810      0.833882
# 11  0.267916  0.892979  0.209353      0.909539
# 12  0.220463  0.918236  0.289719      0.884868
# 13  0.191378  0.925514  0.187140      0.930921
# 14  0.163419  0.941353  0.220127      0.904605
# 15  0.163395  0.942637  0.203273      0.925987
# 16  0.140135  0.949914  0.199663      0.925987
# 17  0.104342  0.964041  0.183023      0.929276
# 18  0.104413  0.958048  0.155775      0.945724
# 19  0.100424  0.965753  0.119507      0.958882
# 20  0.100976  0.962757  0.236328      0.916118
# 21  0.082279  0.971747  0.175288      0.940789
# 22  0.080942  0.972603  0.180157      0.952303
# 23  0.079583  0.971318  0.165579      0.957237
# 24  0.067732  0.977312  0.176570      0.927632
# 25  0.075474  0.971747  0.151894      0.967105
# 26  0.054390  0.982877  0.198194      0.957237
# 27  0.052552  0.983305  0.121403      0.957237
# 28  0.060619  0.976455  0.185029      0.945724
# 29  0.063006  0.978596  0.113356      0.970395

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
for i in glob("/kaggle/input/yawn-test-data/imgs/*"):
    im = plt.imread(i)
    plt.imshow(im)
    img = tf.expand_dims(im,axis = 0)
    if np.argmax(np.squeeze(np.round(model(img)))) == 0:
        print("Prediction : Yawn")
    else:
        print("Prediction : Not Yawning")
    plt.show()
# Out:
# Prediction : Yawn
# Prediction : Yawn
# Prediction : Not Yawning
# Prediction : Not Yawning
# Prediction : Not Yawning
# Prediction : Yawn
# Prediction : Yawn
# Prediction : Not Yawning
